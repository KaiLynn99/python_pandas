# %%
import pandas as pd
import matplotlib.pyplot as plt
# 차트에 한글 깨지지 않도록 차트 폰트변경
plt.rcParams['font.family'] = 'Malgun Gothic'
# 차트에 "-"문자 깨짐 방지
plt.rcParams['axes.unicode_minus'] = False

# %%
df = pd.DataFrame([
    {"이름": "김민수", "성별": "남", "나이": 23},
    {"이름": "이영희", "성별": "여", "나이": 25},
    {"이름": "박철수", "성별": "남", "나이": 27},
    {"이름": "최지영", "성별": "여", "나이": 24},
    {"이름": "정우진", "성별": "남", "나이": 31},
    {"이름": "강수진", "성별": "여", "나이": 29},
    {"이름": "윤현우", "성별": "남", "나이": 35},
    {"이름": "한지민", "성별": "여", "나이": 26},
    {"이름": "조성호", "성별": "남", "나이": 42},
    {"이름": "서유진", "성별": "여", "나이": 33},
    {"이름": "임재현", "성별": "남", "나이": 38},
    {"이름": "오수민", "성별": "여", "나이": 30},
    {"이름": "장동현", "성별": "남", "나이": 45},
    {"이름": "배지은", "성별": "여", "나이": 28},
    {"이름": "신준호", "성별": "남", "나이": 52},
    {"이름": "문소연", "성별": "여", "나이": 36},
    {"이름": "권혁준", "성별": "남", "나이": 8},
    {"이름": "노은지", "성별": "여", "나이": 41},
    {"이름": "홍길동", "성별": "남", "나이": 75},
    {"이름": "김하늘", "성별": "남", "나이": 32}
])

df
# Out:
#      이름 성별  나이
# 0   김민수  남  23
# 1   이영희  여  25
# 2   박철수  남  27
# 3   최지영  여  24
# 4   정우진  남  31
# 5   강수진  여  29
# 6   윤현우  남  35
# 7   한지민  여  26
# 8   조성호  남  42
# 9   서유진  여  33
# 10  임재현  남  38
# 11  오수민  여  30
# 12  장동현  남  45
# 13  배지은  여  28
# 14  신준호  남  52
# 15  문소연  여  36
# 16  권혁준  남   8
# 17  노은지  여  41
# 18  홍길동  남  75
# 19  김하늘  남  32

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   이름      20 non-null     str
#  1   성별      20 non-null     str
#  2   나이      20 non-null     int64
# dtypes: int64(1), str(2)
# memory usage: 612.0 bytes

# %%
df.describe()
# Out:
#               나이
# count  20.000000
# mean   34.000000
# std    13.459491
# min     8.000000
# 25%    26.750000
# 50%    31.500000
# 75%    38.750000
# max    75.000000

# %%
df["나이"].describe()
# Out:
# count    20.000000
# mean     34.000000
# std      13.459491
# min       8.000000
# 25%      26.750000
# 50%      31.500000
# 75%      38.750000
# max      75.000000
# Name: 나이, dtype: float64

# %%
df["성별"].describe()
# Out:
# count     20
# unique     2
# top        남
# freq      11
# Name: 성별, dtype: object

# %%
s = df["성별"].value_counts()
s
# Out:
# 성별
# 남    11
# 여     9
# Name: count, dtype: int64

# %%
type(s)
# Out:
# pandas.Series

# %%
df["성별"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='성별'>

# %%
df["성별"].value_counts().plot(kind="pie")
# Out:
# <Axes: >

# %%
df["나이"].describe()
# Out:
# count    20.000000
# mean     34.000000
# std      13.459491
# min       8.000000
# 25%      26.750000
# 50%      31.500000
# 75%      38.750000
# max      75.000000
# Name: 나이, dtype: float64

# %%
df["나이"].plot(kind="hist", bins=8)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df["나이"].plot(kind="box")
# Out:
# <Axes: >

# %% [markdown]
# #### [실습]

# %%
import pandas as pd

# 직원 데이터 생성
df = pd.DataFrame({
    '사번': [
        'E001', 'E002', 'E003', 'E004', 'E005',
        'E006', 'E007', 'E008', 'E009', 'E010',
        'E011', 'E012', 'E013', 'E014', 'E015',
        'E016', 'E017', 'E018', 'E019', 'E020',
        'E021', 'E022'
    ],

    '이름': [
        '김민수', '이영희', '박철수', '최지영', '정수진',
        '강현우', '윤서연', '한준호', '오지훈', '서민지',
        '임성호', '장유진', '조현우', '배수빈', '문지훈',
        '신예은', '권도윤', '황지민', '송준혁', '김서현',
        '이도현', '박유나'
    ],

    '부서': [
        '개발팀', '마케팅팀', '개발팀', '인사팀', '영업팀',
        '개발팀', '마케팅팀', '영업팀', '개발팀', '인사팀',
        '영업팀', '개발팀', '마케팅팀', '영업팀', '개발팀',
        '인사팀', '마케팅팀', '개발팀', '영업팀', '개발팀',
        '마케팅팀', '인사팀'
    ],

    '성별': [
        '남', '여', '남', '여', '여',
        '남', '여', '남', '남', '여',
        '남', '여', '남', '여', '남',
        '여', '남', '여', '남', '여',
        '남', '여'
    ],

    '나이': [
        28, 31, 26, 35, 29,
        42, 27, 33, 30, 38,
        45, 25, 34, 29, 41,
        32, 36, 28, 39, 27,
        44, 30
    ],

    '연봉': [
        4200, 5100, 3900, 5800, 4500,
        7200, 4100, 5600, 4700, 6300,
        8100, 3800, 5900, 4400, 6900,
        5200, 6100, 4300, 6700, 4000,
        7600, 4800
    ],

    '근속년수': [
        3, 5, 2, 8, 4,
        15, 2, 7, 5, 11,
        18, 1, 6, 3, 14,
        6, 9, 3, 12, 2,
        16, 5
    ],

    '평가등급': [
        1, 2, 1, 3, 2,
        1, 2, 1, 3, 2, 
        1, 1, 2, 3, 1,
        2, 1, 2, 1, 3,
        1, 2
    ]
})

df
# Out:
#       사번   이름    부서 성별  나이    연봉  근속년수  평가등급
# 0   E001  김민수   개발팀  남  28  4200     3     1
# 1   E002  이영희  마케팅팀  여  31  5100     5     2
# 2   E003  박철수   개발팀  남  26  3900     2     1
# 3   E004  최지영   인사팀  여  35  5800     8     3
# 4   E005  정수진   영업팀  여  29  4500     4     2
# 5   E006  강현우   개발팀  남  42  7200    15     1
# 6   E007  윤서연  마케팅팀  여  27  4100     2     2
# 7   E008  한준호   영업팀  남  33  5600     7     1
# 8   E009  오지훈   개발팀  남  30  4700     5     3
# 9   E010  서민지   인사팀  여  38  6300    11     2
# 10  E011  임성호   영업팀  남  45  8100    18     1
# 11  E012  장유진   개발팀  여  25  3800     1     1
# 12  E013  조현우  마케팅팀  남  34  5900     6     2
# 13  E014  배수빈   영업팀  여  29  4400     3     3
# 14  E015  문지훈   개발팀  남  41  6900    14     1
# 15  E016  신예은   인사팀  여  32  5200     6     2
# 16  E017  권도윤  마케팅팀  남  36  6100     9     1
# 17  E018  황지민   개발팀  여  28  4300     3     2
# 18  E019  송준혁   영업팀  남  39  6700    12     1
# 19  E020  김서현   개발팀  여  27  4000     2     3
# 20  E021  이도현  마케팅팀  남  44  7600    16     1
# 21  E022  박유나   인사팀  여  30  4800     5     2

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 22 entries, 0 to 21
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   사번      22 non-null     str
#  1   이름      22 non-null     str
#  2   부서      22 non-null     str
#  3   성별      22 non-null     str
#  4   나이      22 non-null     int64
#  5   연봉      22 non-null     int64
#  6   근속년수    22 non-null     int64
#  7   평가등급    22 non-null     int64
# dtypes: int64(4), str(4)
# memory usage: 1.5 KB

# %%
df["부서"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='부서'>

# %%
df["성별"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='성별'>

# %%
df["연봉"].plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
df["근속년수"].plot(kind="hist", bins = 10)
# Out:
# <Axes: ylabel='Frequency'>

# %%
vr = df["평가등급"].astype("category").describe()

# %%
vr.plot(kind="bar")
# Out:
# <Axes: >
