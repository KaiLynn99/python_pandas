# %%
import pandas as pd

# 직원 데이터 생성
df = pd.DataFrame({
    '사번': [
        'E001', 'E002', 'E003', 'E004', 'E005',
        'E006', 'E007', 'E008', 'E009', 'E010',
        'E011', 'E012', 'E013', 'E014', 'E015',
        'E016', 'E017', 'E018', 'E019', 'E020',
        'E021', 'E022'
    ],

    '이름': [
        '김민수', '이영희', '박철수', '최지영', '정수진',
        '강현우', '윤서연', '한준호', '오지훈', '서민지',
        '임성호', '장유진', '조현우', '배수빈', '문지훈',
        '신예은', '권도윤', '황지민', '송준혁', '김서현',
        '이도현', '박유나'
    ],

    '부서': [
        '개발팀', '마케팅팀', '개발팀', '인사팀', '영업팀',
        '개발팀', '마케팅팀', '영업팀', '개발팀', '인사팀',
        '영업팀', '개발팀', '마케팅팀', '영업팀', '개발팀',
        '인사팀', '마케팅팀', '개발팀', '영업팀', '개발팀',
        '마케팅팀', '인사팀'
    ],

    '성별': [
        '남', '여', '남', '여', '여',
        '남', '여', '남', '남', '여',
        '남', '여', '남', '여', '남',
        '여', '남', '여', '남', '여',
        '남', '여'
    ],

    '나이': [
        28, 31, 26, 35, 29,
        42, 27, 33, 30, 38,
        45, 25, 34, 29, 41,
        32, 36, 28, 39, 27,
        44, 30
    ],

    '연봉': [
        4200, 5100, 3900, 5800, 4500,
        7200, 4100, 5600, 4700, 6300,
        8100, 3800, 5900, 4400, 6900,
        5200, 6100, 4300, 6700, 4000,
        7600, 4800
    ],

    '근속년수': [
        3, 5, 2, 8, 4,
        15, 2, 7, 5, 11,
        18, 1, 6, 3, 14,
        6, 9, 3, 12, 2,
        16, 5
    ],

    '평가등급': [
        'A', 'B', 'A', 'C', 'B',
        'A', 'B', 'A', 'C', 'B',
        'A', 'A', 'B', 'C', 'A',
        'B', 'A', 'B', 'A', 'C',
        'A', 'B'
    ]
})

print(df)
# Out:
#       사번   이름    부서 성별  나이    연봉  근속년수 평가등급
# 0   E001  김민수   개발팀  남  28  4200     3    A
# 1   E002  이영희  마케팅팀  여  31  5100     5    B
# 2   E003  박철수   개발팀  남  26  3900     2    A
# 3   E004  최지영   인사팀  여  35  5800     8    C
# 4   E005  정수진   영업팀  여  29  4500     4    B
# 5   E006  강현우   개발팀  남  42  7200    15    A
# 6   E007  윤서연  마케팅팀  여  27  4100     2    B
# 7   E008  한준호   영업팀  남  33  5600     7    A
# 8   E009  오지훈   개발팀  남  30  4700     5    C
# 9   E010  서민지   인사팀  여  38  6300    11    B
# 10  E011  임성호   영업팀  남  45  8100    18    A
# 11  E012  장유진   개발팀  여  25  3800     1    A
# 12  E013  조현우  마케팅팀  남  34  5900     6    B
# 13  E014  배수빈   영업팀  여  29  4400     3    C
# 14  E015  문지훈   개발팀  남  41  6900    14    A
# 15  E016  신예은   인사팀  여  32  5200     6    B
# 16  E017  권도윤  마케팅팀  남  36  6100     9    A
# 17  E018  황지민   개발팀  여  28  4300     3    B
# 18  E019  송준혁   영업팀  남  39  6700    12    A
# 19  E020  김서현   개발팀  여  27  4000     2    C
# ...

# %% [markdown]
# 1. 기본 구조(RangeIndex, Data columns, Non-Null Count, Dtype) 확인

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 22 entries, 0 to 21
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   사번      22 non-null     str
#  1   이름      22 non-null     str
#  2   부서      22 non-null     str
#  3   성별      22 non-null     str
#  4   나이      22 non-null     int64
#  5   연봉      22 non-null     int64
#  6   근속년수    22 non-null     int64
#  7   평가등급    22 non-null     str
# dtypes: int64(3), str(5)
# memory usage: 1.5 KB

# %% [markdown]
# 2. 행 개수, 열 개수, 열 이름 정보 확인

# %%
# 행 개수
df.shape[0]
# Out:
# 22

# %%
# 열 개수
df.shape[1]
# Out:
# 8

# %%
# 열 이름
df.columns
# Out:
# Index(['사번', '이름', '부서', '성별', '나이', '연봉', '근속년수', '평가등급'], dtype='str')

# %% [markdown]
# 3. 레이블 인덱스 확인

# %%
df.index
# Out:
# RangeIndex(start=0, stop=22, step=1)

# %% [markdown]
# 4. 열들의 데이터 타입 확인

# %%
df.dtypes
# Out:
# 사번        str
# 이름        str
# 부서        str
# 성별        str
# 나이      int64
# 연봉      int64
# 근속년수    int64
# 평가등급      str
# dtype: object

# %% [markdown]
# 5. 처음3행, 마지막 3행 데이터 확인

# %%
# 처음3행
df.head(3)
# Out:
#      사번   이름    부서 성별  나이    연봉  근속년수 평가등급
# 0  E001  김민수   개발팀  남  28  4200     3    A
# 1  E002  이영희  마케팅팀  여  31  5100     5    B
# 2  E003  박철수   개발팀  남  26  3900     2    A

# %%
# 마지막 3행
df.tail(3)
# Out:
#       사번   이름    부서 성별  나이    연봉  근속년수 평가등급
# 19  E020  김서현   개발팀  여  27  4000     2    C
# 20  E021  이도현  마케팅팀  남  44  7600    16    A
# 21  E022  박유나   인사팀  여  30  4800     5    B

# %% [markdown]
# 6. 부서, 성별, 평가등급 열의 고유값(unique)과 고유값 개수(nunique) 확인

# %%
df["부서"].unique()
# Out:
# <StringArray>
# ['개발팀', '마케팅팀', '인사팀', '영업팀']
# Length: 4, dtype: str

# %%
df["성별"].unique()
# Out:
# <StringArray>
# ['남', '여']
# Length: 2, dtype: str

# %%
df["평가등급"].unique()
# Out:
# <StringArray>
# ['A', 'B', 'C']
# Length: 3, dtype: str

# %% [markdown]
# 7. 부서, 성별, 평가등급 열의 값별 빈도(value_counts) 확인

# %%
df["부서"].value_counts()
# Out:
# 부서
# 개발팀     8
# 마케팅팀    5
# 영업팀     5
# 인사팀     4
# Name: count, dtype: int64

# %%
df["성별"].value_counts()
# Out:
# 성별
# 남    11
# 여    11
# Name: count, dtype: int64

# %%
df["평가등급"].value_counts()
# Out:
# 평가등급
# A    10
# B     8
# C     4
# Name: count, dtype: int64
